# %% [markdown]
# Autor: Julian Peña Duarte
#
# Proyecto: Lideres sociales
#
# Fecha: 2021-05-27
#
# Propósito: gráficos y hallazgos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

# %%
df_final=pd.read_csv('asesinatos lideres(datos)/somos_defensores_2016_2020.csv', parse_dates=['fecha'])

# %%
df_final.head()
# Out:
#        fecha        departamento             municipio  \
# 0 2016-01-14            CASANARE  San Luis de Palenque
# 1 2016-01-16  NORTE DE SANTANDER           San Calixto
# 2 2016-01-24              NARINO                Tumaco
# 3 2016-01-29               HUILA             Algeciras
# 4 2016-02-02              NARINO              la Unión
#
#                      victima  \
# 0  Mario Alexi Tarache Pérez
# 1          Nelly Amaya Pérez
# 2        Johan Alexis Vargas
# 3       Robinson Ávila Ortiz
# 4      Senelia Rengifo Gómez
#
#                                         organizacion      tipo de lider  \
# 0  Junta de Acción Comunal (JAC) de la vereda Are...      Líder Comunal
# 1       Junta de Acción Comunal del barrio Guamalito      Líder Comunal
# 2  Coordinación Nacional de Organizaciones y Comu...         Líder Afro
# 3          Comunidad del Bajo Quebradón de Algeciras  Líder Comunitario
# 4  Centro Educativo Cimarronas y Sindicato Magist...     Líder Sindical
#
#   presunto responsable  mes   año  dia  semestre Tipo defensor  \
# 0        Paramilitares    1  2016   14         1      Communal
# 1        Paramilitares    1  2016   16         1      Communal
# 2        Paramilitares    1  2016   24         1          Afro
# 3         Desconocidos    1  2016   29         1      Communal
# 4        Paramilitares    2  2016    2         1         Union
#
#   presumed responsible
# 0       Paramilitaries
# 1       Paramilitaries
# 2       Paramilitaries
# 3              Unknown
# 4       Paramilitaries

# %% [markdown]
# Gráfica serie de tiempo de líderes asesinados por año y semestre

# %%
data_by_year_semester = df_final.groupby(['año', 'semestre']) # Agrupo por año y semestre

# %%
data_by_year_semester_count = data_by_year_semester['victima'].agg('count')

# %%
#Ajuste de parametros
sns.set(font_scale=1.5,style="whitegrid")
plt.rcParams["figure.figsize"] = [16.0, 8.0]

# %%
data_by_year_semester_count.plot(color='#5b95c2', linewidth=4)
plt.ylabel('Killings',fontsize = 25)
plt.xlabel("(Year, Semester)",fontsize = 25)
plt.savefig(r'graficos\Number of  killings of human rights defenders.pdf')

# %% [markdown]
# Gráfica de barras categorías de defensores más afectadas

# %%
df_tipo_defensor = df_final.groupby('Tipo defensor').size().reset_index(name='Count') #Agrupo por tipo de defensor

# %%
df_tipo_defensor.sort_values(by=['Count'], inplace=True, ascending=False)

# %%
df_tipo_defensor
# Out:
#              Tipo defensor  Count
# 1                 Communal    265
# 3               Indigenous    103
# 2  Farmer or environmental    100
# 0                     Afro     28
# 6                    Union     17
# 9       Youth or education     16
# 7                  Victims     11
# 4                    LGTBI      9
# 5                    Other      9
# 8                    Women      2

# %%
df_tipo_defensor['percent']= df_tipo_defensor['Count']/560*100

# %%
df_tipo_defensor_percent=df_tipo_defensor.loc[:,('Tipo defensor','percent')]

# %%
sns.set(font_scale=1.5,style="whitegrid")
plt.rcParams["figure.figsize"] = [12.0, 6.0]
ax=sns.barplot(x='Count', y='Tipo defensor',  data=df_tipo_defensor,palette="cubehelix")
ax.set_xlabel('Killings',fontsize = 20)
ax.set_ylabel('Defender type',fontsize = 20)
plt.savefig(r'graficos\defender_type.jpg', bbox_inches='tight');

# %%
sns.set(font_scale=1.75,style="whitegrid")
plt.rcParams["figure.figsize"] = [14, 7]

colors=['#ffa04d', '#fccf5e','#a8a495','#d9ccb3','#e1e0d6','#06c2ac', '#97dfd7','#5b95c2', '#5684a0', '#507991','#8f8ce7',
       '#040348']

ax=sns.barplot(x='percent', y='Tipo defensor',  data=df_tipo_defensor_percent, palette=colors)
ax.set_xlabel('Killings percentage',fontsize = 25)
ax.set_ylabel('Defender type',fontsize = 25)
ax.set_xlim(ax.get_xlim()[::-1])

#move ticks to the right
ax.yaxis.tick_right()
    

for p in ax.patches:
    width = p.get_width()
    ax.text(width+2.25,      
            p.get_y() + p.get_height() / 2 +0.025, 
            '{:1.2f}'.format(width), 
            ha = 'left',   
            va = 'center', color='black', fontsize='x-small') 

plt.savefig(r'graficos\defender_type_percent.pdf', bbox_inches='tight');

# %% [markdown]
# Grafica de tortas presunto responsable

# %%
df_by_presumed_responsible = df_final.groupby('presumed responsible').size().reset_index(name='Count')

# %%
df_by_presumed_responsible.sort_values(by=['Count'], inplace=True, ascending=False)

# %%
df_by_presumed_responsible
# Out:
#   presumed responsible  Count
# 6              Unknown    360
# 4       Paramilitaries     97
# 2      FARC dissidents     49
# 0                  ELN     25
# 5         Public force     22
# 1                  EPL      4
# 3     Intimate partner      3

# %%
colors=['#ffa04d', '#fccf5e','#d9ccb3','#e1e0d6', '#97dfd7','#5b95c2', '#5684a0', '#507991','#8f8ce7',
       '#040348']
labels=['Unknown: 64.29%','Paramilitaries: 17.32%', 'FARC dissidents: 8.75%', 'ELN: 4.46%','Public force: 3.93%', 'EPL: 0.71%','Intimate partner: 0.54%']
plt.rcParams['font.size'] = 16
plt.rcParams["font.family"] = "Times New Roman"
fig1, ax1 = plt.subplots()

ax1.pie('Count', data=df_by_presumed_responsible, pctdistance=0.85, colors=colors);

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.legend(labels)
plt.savefig(r'graficos\presumed responsible1.pdf', bbox_inches='tight');

# %%
homicidios=pd.read_csv('homicidios(datos)/homicidios_2016_2020.csv')

# %%
homicidios
# Out:
#           DEPARTAMENTO       MUNICIPIO  CODIGO DANE  \
# 0             AMAZONAS    LETICIA (CT)   91001000.0
# 1            ANTIOQUIA   MEDELLÍN (CT)    5001000.0
# 2            ANTIOQUIA     SABANALARGA    5628000.0
# 3            ANTIOQUIA         YOLOMBÓ    5890000.0
# 4              BOLIVAR  CARTAGENA (CT)   13001000.0
# ...                ...             ...          ...
# 55422  VALLE DEL CAUCA       CALI (CT)   76001000.0
# 55423  VALLE DEL CAUCA       CALI (CT)   76001000.0
# 55424  VALLE DEL CAUCA           YUMBO   76892000.0
# 55425  VALLE DEL CAUCA           YUMBO   76892000.0
# 55426  VALLE DEL CAUCA           YUMBO   76892000.0
#
#                       ARMAS MEDIOS FECHA HECHO     GENERO AGRUPA EDAD PERSONA  \
# 0      ARMA BLANCA / CORTOPUNZANTE  2016-01-01  MASCULINO             ADULTOS
# 1      ARMA BLANCA / CORTOPUNZANTE  2016-01-01  MASCULINO             ADULTOS
# 2      ARMA BLANCA / CORTOPUNZANTE  2016-01-01  MASCULINO             ADULTOS
# 3      ARMA BLANCA / CORTOPUNZANTE  2016-01-01  MASCULINO             ADULTOS
# 4      ARMA BLANCA / CORTOPUNZANTE  2016-01-01  MASCULINO             ADULTOS
# ...                            ...         ...        ...                 ...
# 55422                ARMA DE FUEGO  2020-12-31  MASCULINO             ADULTOS
# 55423  ARMA BLANCA / CORTOPUNZANTE  2020-12-31  MASCULINO             ADULTOS
# 55424                ARMA DE FUEGO  2020-12-31  MASCULINO             ADULTOS
# 55425                ARMA DE FUEGO  2020-12-31  MASCULINO             ADULTOS
# 55426                ARMA DE FUEGO  2020-12-31  MASCULINO             ADULTOS
#
#        CANTIDAD  mes   año  dia  semestre
# 0           1.0    1  2016    1         1
# 1           1.0    1  2016    1         1
# 2           1.0    1  2016    1         1
# 3           1.0    1  2016    1         1
# 4           1.0    1  2016    1         1
# ...         ...  ...   ...  ...       ...
# 55422       1.0   12  2020   31         2
# 55423       1.0   12  2020   31         2
# 55424       1.0   12  2020   31         2
# 55425       1.0   12  2020   31         2
# 55426       1.0   12  2020   31         2
#
# [55427 rows x 12 columns]

# %%
#borro la información del segundo semestre de 2020 porque para esa fecha no tengo la información de los lideres 
homicidios.drop(homicidios.loc[(homicidios['año']==2020) & (homicidios['semestre']==2)].index, inplace=True)

# %%
homicidios_by_year_semester = homicidios.groupby(['año', 'semestre'])

# %%
homicidios_by_year_semester_count = homicidios_by_year_semester['CANTIDAD'].agg('sum')

# %%
homicidios_by_year_semester_count.plot(color='darkblue', linewidth=4);

# %%
df_homicidios=homicidios_by_year_semester_count.to_frame()
df_homicidios
# Out:
#                CANTIDAD
# año  semestre
# 2016 1           6008.0
#      2           6156.0
# 2017 1           5808.0
#      2           6271.0
# 2018 1           6279.0
#      2           6388.0
# 2019 1           6223.0
#      2           6433.0
# 2020 1           5416.0

# %%
df_lideres=data_by_year_semester_count.to_frame()
df_lideres
# Out:
#                victima
# año  semestre
# 2016 1              39
#      2              41
# 2017 1              51
#      2              51
# 2018 1              73
#      2              82
# 2019 1              60
#      2              64
# 2020 1              95

# %%
df_temp=pd.merge(df_homicidios,df_lideres, how='outer',on = ['año', 'semestre'])
df_temp
# Out:
#                CANTIDAD  victima
# año  semestre
# 2016 1           6008.0       39
#      2           6156.0       41
# 2017 1           5808.0       51
#      2           6271.0       51
# 2018 1           6279.0       73
#      2           6388.0       82
# 2019 1           6223.0       60
#      2           6433.0       64
# 2020 1           5416.0       95

# %%
df_temp['homicides_index']=(df_temp['CANTIDAD']/6008.0)*100-100
df_temp['defenders_index']=(df_temp['victima']/39)*100-100

# %%
df_temp
# Out:
#                CANTIDAD  victima  homicides_index  defenders_index
# año  semestre
# 2016 1           6008.0       39         0.000000         0.000000
#      2           6156.0       41         2.463382         5.128205
# 2017 1           5808.0       51        -3.328895        30.769231
#      2           6271.0       51         4.377497        30.769231
# 2018 1           6279.0       73         4.510652        87.179487
#      2           6388.0       82         6.324900       110.256410
# 2019 1           6223.0       60         3.578562        53.846154
#      2           6433.0       64         7.073901        64.102564
# 2020 1           5416.0       95        -9.853529       143.589744

# %%
plt.rcParams["figure.figsize"] = [12.0, 6.0]
fig, ax1 = plt.subplots()
ax2 = ax1.twinx() 

df_temp.victima.plot(color='darkblue', ax=ax1, linewidth=3, label='Defender killings')
df_temp.CANTIDAD.plot(color='#06c2ac', ax=ax2, style='--', linewidth=3, label='Homicides')
ax1.legend()
ax2.legend(loc=4)
plt.grid()
plt.tight_layout()
ax1.set_xlabel("(Year, Semester)",fontsize = 20)
ax1.set_ylabel('Defender killings', color='darkblue')
ax2.set_ylabel('Homicides', color='#06c2ac')
plt.savefig(r'graficos\Number of  killings of human rights defenders vs homicides.jpg', bbox_inches='tight');

# %%
plt.rcParams["figure.figsize"] = [12.0, 6.0]
fig, ax1 = plt.subplots()
ax2 = ax1.twinx() 
a,b = -13,150
ax1.set_ylim(a,b)
ax2.set_ylim(a,b)

df_temp.defenders_index.plot(color='darkblue', ax=ax1, linewidth=3, label='Defender killings')
df_temp.homicides_index.plot(color='#06c2ac', ax=ax2, style='--', linewidth=3, label='Homicides')
ax1.legend(loc=1)
ax2.legend(loc=2)
plt.grid()
plt.tight_layout()
ax1.set_xlabel("(Year, Semester)",fontsize = 20)
ax1.set_ylabel('Percentage change compared to (2016,1)', color='black')
#ax2.set_ylabel('Percentage change compared to (2016,1)', color='#06c2ac')
plt.savefig(r'graficos\Number of  killings of human rights defenders vs homicides(same scale).jpg', bbox_inches='tight');

# %%
asesinatos_lideres=pd.read_csv('asesinatos lideres(datos)/asesinatos_lideres_departamento.csv')

# %%
homicidios_departamento=pd.read_csv('homicidios(datos)/tasa_homicidios_departamento.csv')

# %%
df=pd.merge(asesinatos_lideres,homicidios_departamento, how='outer',on = 'departamento')

# %%
df.set_index('departamento', inplace=True)

# %%
df = df[df["victimas"].notna()]

# %%
df.rename(columns={'victimas':'Defender killings (left)', 'tasa_de_homicidios':'Homicide rate'}, inplace=True)

# %%
df['Defender killings rate (left)']=(df['Defender killings (left)']/
                                                    df['PoblacióntotalDANE'])*100000

# %%
del df['Defender killings (left)']

# %%
del df['PoblacióntotalDANE']

# %%
df.sort_values(by=['Defender killings rate (left)'], inplace=True, ascending=False)

# %%
df=df[["Defender killings rate (left)", "Homicide rate"]]

# %%
df
# Out:
#                     Defender killings rate (left)  Homicide rate
# departamento
# CAUCA                                    9.044878      47.394762
# PUTUMAYO                                 8.909549      40.452737
# ARAUCA                                   6.282219      40.958036
# CAQUETA                                  5.441201      32.148235
# VICHADA                                  5.172931      25.109383
# CHOCO                                    3.493777      44.452791
# NORTE DE SANTANDER                       3.091296      37.751460
# GUAVIARE                                 2.589041      23.836107
# NARINO                                   1.713745      30.580235
# CASANARE                                 1.598856      18.896429
# META                                     1.278597      26.653319
# HUILA                                    1.253049      19.902249
# RISARALDA                                1.240002      24.950547
# CESAR                                    1.219990      19.938966
# ANTIOQUIA                                1.195726      31.781086
# CORDOBA                                  1.118639      18.563767
# VALLE DEL CAUCA                          0.735822      48.187327
# MAGDALENA                                0.615814      18.055419
# LA GUAJIRA                               0.577004      19.998925
# BOLIVAR                                  0.460636      18.196160
# TOLIMA                                   0.422569      19.842033
# CALDAS                                   0.402470      18.459751
# QUINDIO                                  0.347818      36.279304
# BOYACA                                   0.311938       6.785876
# SANTANDER                                0.239141      12.844189
# SUCRE                                    0.227997      15.324999
# CUNDINAMARCA                             0.213964      14.328497
# ATLANTICO                                0.196420      21.249297
# BOGOTA                                   0.066867      14.858857

# %%
plt.rcParams["figure.figsize"] = [18.0, 8.0]
sns.set(font_scale=1.5,style="whitegrid")
plt.rcParams['font.size'] = 16
colors=['#6832e3','#acc2d9']
df.plot( kind= 'bar' , secondary_y= 'Homicide rate' ,rot=90, color=colors, width=0.8)

ax1, ax2 = plt.gcf().get_axes() 

ax1.set_ylabel('Defender killings rate',fontsize = 25)
ax2.set_ylabel('Homicide rate',fontsize = 25)
ax1.set_xlabel('Department',fontsize = 25)


plt.savefig('graficos\defenders_homicides.jpg', bbox_inches='tight');
plt.show()

# %%
data_by_defender_year_semester = df_final.groupby(['Tipo defensor','año', 'semestre']) # Agrupo por año y semestre

# %%
data_by_defender_year_semester_count = data_by_defender_year_semester['victima'].agg('count')

# %%
data_by_defender_year_semester_count.to_frame()
# Out:
#                                   victima
# Tipo defensor      año  semestre
# Afro               2016 1               5
#                         2               2
#                    2017 1               4
#                         2               3
#                    2018 1               2
# ...                                   ...
# Youth or education 2017 2               3
#                    2018 1               2
#                         2               3
#                    2019 2               1
#                    2020 1               2
#
# [82 rows x 1 columns]

# %%
type_defender_timeseries =data_by_defender_year_semester_count.unstack('Tipo defensor')

# %%
type_defender_timeseries
# Out:
# Tipo defensor  Afro  Communal  Community  Farmer or environmental  Indigenous  \
# año  semestre
# 2016 1          5.0       7.0        6.0                      6.0         8.0
#      2          2.0      13.0        4.0                      7.0         7.0
# 2017 1          4.0      13.0       10.0                      7.0         5.0
#      2          3.0      14.0       10.0                      7.0         7.0
# 2018 1          2.0      23.0       13.0                     14.0        13.0
#      2          3.0      37.0        9.0                     15.0        13.0
# 2019 1          3.0      18.0       22.0                      8.0         6.0
#      2          2.0      15.0        6.0                     11.0        26.0
# 2020 1          4.0      28.0       15.0                     24.0        18.0
#
# Tipo defensor  LGTBI  Other  Union  Victims  Women  Youth or education
# año  semestre
# 2016 1           2.0    1.0    2.0      1.0    NaN                 1.0
#      2           1.0    1.0    2.0      2.0    NaN                 2.0
# 2017 1           3.0    2.0    3.0      1.0    1.0                 2.0
#      2           NaN    4.0    2.0      1.0    NaN                 3.0
# 2018 1           1.0    NaN    3.0      2.0    NaN                 2.0
#      2           NaN    NaN    1.0      1.0    NaN                 3.0
# 2019 1           1.0    NaN    1.0      1.0    NaN                 NaN
#      2           NaN    1.0    NaN      1.0    1.0                 1.0
# 2020 1           1.0    NaN    3.0      NaN    NaN                 2.0

# %%
colors=[ '#d5869d','darkblue','#06c2ac','#6832e3', '#748b97']
type_defender_timeseries.iloc[:,:5].plot(color=colors, style=["--","-","-.",":", "-"])
plt.ylabel('Killings',fontsize = 20)
plt.xlabel("(Year, Semester)",fontsize = 20)
plt.legend()
plt.savefig(r'graficos\Number of  killings by type of defender.png');

# %%
data_by_day = df_final.groupby(['dia'])

# %%
data_by_day_count = data_by_day['victima'].agg('count')

# %%
data_by_day_count.plot(kind='bar', color='darkcyan')
plt.ylabel('Killings',fontsize = 20)
plt.xlabel("Day",fontsize = 20)
plt.savefig(r'graficos\Number of  killings by day.png');

# %%
df_final['day_week'] = df_final['fecha'].dt.day_name()

# %%
data_by_day_week = df_final.groupby(['day_week'])

# %%
data_by_day_week_count = data_by_day_week['victima'].agg('count')

# %%
data_by_day_week_count
# Out:
# day_week
# Friday        79
# Monday        74
# Saturday      70
# Sunday       101
# Thursday      89
# Tuesday       81
# Wednesday     62
# Name: victima, dtype: int64

# %%
day_week_df=data_by_day_week_count.to_frame()

# %%
day_week_df.sort_values(by=['victima'], inplace=True, ascending=False)

# %%
day_week_df.plot(kind='bar', color='#380282')
plt.gca().get_legend().remove()
plt.ylabel('Killings',fontsize = 20)
plt.xlabel("Day of week",fontsize = 20)
plt.savefig(r'graficos\Number of  killings by day of week.png');
